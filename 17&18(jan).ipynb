# %%
print(uber_data.shape)
print(uber_data.info())
print(uber_data.describe())
# Out:
# (1156, 7)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB
# None
#              MILES*
# count   1156.000000
# mean      21.115398
# std      359.299007
# min        0.500000
# 25%        2.900000
# 50%        6.000000
# 75%       10.400000
# max    12204.700000

# %%
import pandas as pd
uber_data=pd.read_csv("C:\\Users\\Proxy1\\Downloads\\Uber.csv")
uber_data.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
print(uber_data.isnull().sum())
# Out:
# START_DATE*      0
# END_DATE*        1
# CATEGORY*        1
# START*           1
# STOP*            1
# MILES*           0
# PURPOSE*       503
# dtype: int64

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\Proxy1\\Downloads\\Uber.csv",
              dtype={"Age": int},
              skiprows=1,
              nrows=5,
              na_values=["NA","Unknown"])
print(df)
# Out:
#    1/1/2016 21:11  1/1/2016 21:17  Business      Fort Pierce    Fort Pierce.1  \
# 0   1/2/2016 1:25   1/2/2016 1:37  Business      Fort Pierce      Fort Pierce
# 1  1/2/2016 20:25  1/2/2016 20:38  Business      Fort Pierce      Fort Pierce
# 2  1/5/2016 17:31  1/5/2016 17:45  Business      Fort Pierce      Fort Pierce
# 3  1/6/2016 14:42  1/6/2016 15:49  Business      Fort Pierce  West Palm Beach
# 4  1/6/2016 17:15  1/6/2016 17:19  Business  West Palm Beach  West Palm Beach
#
#     5.1   Meal/Entertain
# 0   5.0              NaN
# 1   4.8  Errand/Supplies
# 2   4.7          Meeting
# 3  63.7   Customer Visit
# 4   4.3   Meal/Entertain

# %%
uber_data.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
uber_data.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
uber_data.iloc[0]
# Out:
# START_DATE*    1/1/2016 21:11
# END_DATE*      1/1/2016 21:17
# CATEGORY*            Business
# START*            Fort Pierce
# STOP*             Fort Pierce
# MILES*                    5.1
# PURPOSE*       Meal/Entertain
# Name: 0, dtype: object

# %%
uber_data.iloc[2:8]
# Out:
#       START_DATE*       END_DATE* CATEGORY*           START*            STOP*  \
# 2  1/2/2016 20:25  1/2/2016 20:38  Business      Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business      Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business      Fort Pierce  West Palm Beach
# 5  1/6/2016 17:15  1/6/2016 17:19  Business  West Palm Beach  West Palm Beach
# 6  1/6/2016 17:30  1/6/2016 17:35  Business  West Palm Beach       Palm Beach
# 7  1/7/2016 13:27  1/7/2016 13:33  Business             Cary             Cary
#
#    MILES*         PURPOSE*
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit
# 5     4.3   Meal/Entertain
# 6     7.1          Meeting
# 7     0.8          Meeting

# %%
uber_data.iloc[2:8,1:3]
# Out:
#         END_DATE* CATEGORY*
# 2  1/2/2016 20:38  Business
# 3  1/5/2016 17:45  Business
# 4  1/6/2016 15:49  Business
# 5  1/6/2016 17:19  Business
# 6  1/6/2016 17:35  Business
# 7  1/7/2016 13:33  Business

# %%
import pandas as pd
temp=pd.DataFrame(
    {
        'A':[1,2,3,4],
        'B':[10,20,30,40],
        'C':['2025-1-19','2025-01-21','2025-01-11','2025-01-21']
             })
#object to date
temp.dtypes
# Out:
# A             int64
# B             int64
# C    datetime64[ns]
# dtype: object

# %%
temp['C']=pd.to_datetime(temp['C'])#object to date
temp
# Out:
#    A   B          C
# 0  1  10 2025-01-19
# 1  2  20 2025-01-21
# 2  3  30 2025-01-11
# 3  4  40 2025-01-21

# %%
temp['B']=temp['B'].astype(str)
temp.dtypes
# Out:
# A             int64
# B            object
# C    datetime64[ns]
# dtype: object

# %%
import pandas as pd
temp1=pd.DataFrame(
    {
        'A':[1,2,3,4],
        'B':[10,20,30,40],
        'C':['19-1-2025','21-1-2025','11-1-2025','21-1-2025']
})
#temp['C']=pd.to_datetime(temp['C'])
temp1.dtypes
# Out:
# A     int64
# B     int64
# C    object
# dtype: object

# %%
import pandas as pd
uber_data=pd.read_csv("C:\\Users\\Proxy1\\Downloads\\Uber.csv")
uber_data.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
uber_data['START*'].value_counts() #finding unique values & count
# Out:
# START*
# Cary                201
# Unknown Location    148
# Morrisville          85
# Whitebridge          68
# Islamabad            57
#                    ...
# Florence              1
# Ridgeland             1
# Daytona Beach         1
# Sky Lake              1
# Gampaha               1
# Name: count, Length: 177, dtype: int64

# %%
uber_data['STOP*'].value_counts()
# Out:
# STOP*
# Cary                 203
# Unknown Location     149
# Morrisville           84
# Whitebridge           65
# Islamabad             58
#                     ...
# Daytona Beach          1
# Sand Lake Commons      1
# Sky Lake               1
# Vista East             1
# Ilukwatta              1
# Name: count, Length: 188, dtype: int64

# %%
a=uber_data[uber_data['MILES*']>6]
a
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 6       1/6/2016 17:30    1/6/2016 17:35  Business   West Palm Beach
# 8       1/10/2016 8:05    1/10/2016 8:25  Business              Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business           Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business          New York
# ...                ...               ...       ...               ...
# 1144  12/29/2016 23:14  12/29/2016 23:47  Business  Unknown Location
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 4      West Palm Beach     63.7  Customer Visit
# ...

# %%
a=uber_data[(uber_data['MILES*']>50) & (uber_data['MILES*']<100)]
a
# Out:
#           START_DATE*         END_DATE* CATEGORY*            START*  \
# 4      1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 251   3/19/2016 19:33   3/19/2016 20:39  Business         Galveston
# 295    4/2/2016 12:21    4/2/2016 14:47  Business         Kissimmee
# 296    4/2/2016 16:57    4/2/2016 18:09  Business     Daytona Beach
# 707   8/24/2016 13:01   8/24/2016 15:25  Business  Unknown Location
# 710   8/25/2016 17:19   8/25/2016 19:20  Business  Unknown Location
# 726   8/27/2016 14:01   8/27/2016 15:44  Business            Lahore
# 751    9/6/2016 17:49    9/6/2016 17:49  Business  Unknown Location
# 871  10/28/2016 20:13  10/28/2016 22:00  Business         Asheville
# 873  10/29/2016 17:13  10/29/2016 19:19  Business        Hayesville
# 880  10/30/2016 13:24  10/30/2016 14:37  Business       Bryson City
#
#                 STOP*  MILES*        PURPOSE*
# 4     West Palm Beach    63.7  Customer Visit
# 251           Houston    57.0  Customer Visit
# ...

# %%
b=uber_data[uber_data['START*']=='New York']
b
# Out:
#          START_DATE*        END_DATE* CATEGORY*    START*             STOP*  \
# 10   1/10/2016 15:08  1/10/2016 15:51  Business  New York            Queens
# 22   1/12/2016 16:02  1/12/2016 17:00  Business  New York     Queens County
# 106  2/14/2016 16:35  2/14/2016 17:02  Business  New York  Long Island City
# 423  6/10/2016 15:19  6/10/2016 16:28  Business  New York           Jamaica
#
#      MILES* PURPOSE*
# 10     10.8  Meeting
# 22     15.1  Meeting
# 106    13.0  Meeting
# 423    16.3  Meeting

# %%
a=uber_data[(uber_data['MILES*']>50) & (uber_data['MILES*']<100)]
a=a.iloc[:, 3:6]
a
# Out:
#                START*             STOP*  MILES*
# 4         Fort Pierce   West Palm Beach    63.7
# 251         Galveston           Houston    57.0
# 295         Kissimmee     Daytona Beach    77.3
# 296     Daytona Beach      Jacksonville    80.5
# 707  Unknown Location  Unknown Location    96.2
# 710  Unknown Location  Unknown Location    50.4
# 726            Lahore  Unknown Location    86.6
# 751  Unknown Location  Unknown Location    69.1
# 871         Asheville            Topton    91.8
# 873        Hayesville            Topton    75.7
# 880       Bryson City         Asheville    68.4

# %%
df=uber_data.loc[uber_data['START*'].isin (['New York','Cary'])]
df
# Out:
#              START_DATE*           END_DATE* CATEGORY*    START*  \
# 7    2016-01-07 13:27:00 2016-01-07 13:33:00  Business      Cary
# 8    2016-01-10 08:05:00 2016-01-10 08:25:00  Business      Cary
# 10   2016-01-10 15:08:00 2016-01-10 15:51:00  Business  New York
# 22   2016-01-12 16:02:00 2016-01-12 17:00:00  Business  New York
# 28   2016-01-15 11:43:00 2016-01-15 12:03:00  Business      Cary
# ...                  ...                 ...       ...       ...
# 1049 2016-12-13 20:20:00 2016-12-13 20:29:00  Business      Cary
# 1050 2016-12-14 16:52:00 2016-12-14 17:10:00  Business      Cary
# 1051 2016-12-14 17:22:00 2016-12-14 17:34:00  Business      Cary
# 1052 2016-12-14 17:50:00 2016-12-14 18:00:00  Business      Cary
# 1054 2016-12-15 14:20:00 2016-12-15 14:54:00  Business      Cary
#
#               STOP*  MILES*        PURPOSE*
# 7              Cary     0.8         Meeting
# 8       Morrisville     8.3         Meeting
# 10           Queens    10.8         Meeting
# ...

# %%
a = uber_data.loc[
    (uber_data['MILES*'] > 10) & 
    (uber_data['MILES*'] < 20) & 
    uber_data['STOP*'].isin(['Jamaica', 'Cary']) & 
    uber_data['START*'].isin(['New York', 'Cary'])
]
a.reset_index(inplace=True,drop=True)
a
# Out:
#           START_DATE*           END_DATE* CATEGORY*    START*    STOP*  \
# 0 2016-06-10 15:19:00 2016-06-10 16:28:00  Business  New York  Jamaica
# 1 2016-11-20 17:45:00 2016-11-20 18:37:00  Business      Cary     Cary
# 2 2016-11-22 15:51:00 2016-11-22 16:43:00  Business      Cary     Cary
# 3 2016-12-09 22:03:00 2016-12-09 22:57:00  Business      Cary     Cary
#
#    MILES*         PURPOSE*
# 0    16.3          Meeting
# 1    18.5  Errand/Supplies
# 2    12.7   Customer Visit
# 3    18.9   Customer Visit

# %%
# display all the records whose start city is A
# Step 1: Convert 'START*' and 'STOP*' columns to datetime (replace column names accordingly)
uber_data['START_DATE*'] = pd.to_datetime(uber_data['START_DATE*'], errors='coerce')
uber_data['END_DATE*'] = pd.to_datetime(uber_data['END_DATE*'], errors='coerce')

# Step 2: Filter for records where both START_DATE and STOP_DATE are in January 2016
january_2016_data = uber_data[
    (uber_data['START_DATE*'].dt.year == 2016) & (uber_data['START_DATE*'].dt.month == 1) &
    (uber_data['END_DATE*'].dt.year == 2016) & (uber_data['END_DATE*'].dt.month == 1) &
    (uber_data['START_DATE*'].notnull()) & (uber_data['END_DATE*'].notnull())
]

# Step 3: Display the result
january_2016_data
# Out:
#            START_DATE*           END_DATE* CATEGORY*       START*  \
# 0  2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1  2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2  2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3  2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4  2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
# ..                 ...                 ...       ...          ...
# 56 2016-01-29 13:24:00 2016-01-29 13:47:00  Business       Durham
# 57 2016-01-29 18:31:00 2016-01-29 18:52:00  Business         Cary
# 58 2016-01-29 21:21:00 2016-01-29 21:40:00  Business         Apex
# 59 2016-01-30 16:21:00 2016-01-30 16:33:00  Business         Cary
# 60 2016-01-30 18:09:00 2016-01-30 18:24:00  Business         Apex
#
#               STOP*  MILES*         PURPOSE*
# 0       Fort Pierce     5.1   Meal/Entertain
# 1       Fort Pierce     5.0              NaN
# ...

# %%
# display all the records of Jan-2016 and start city = Cary
# Step 1: Convert 'START*' and 'STOP*' columns to datetime (replace column names accordingly)
uber_data['START_DATE*'] = pd.to_datetime(uber_data['START_DATE*'], errors='coerce')
uber_data['END_DATE*'] = pd.to_datetime(uber_data['END_DATE*'], errors='coerce')

# Step 2: Filter for records where:
#  - Both START_DATE and STOP_DATE are in January 2016
#  - START* city is 'Cary'
#  - Both START_DATE and STOP_DATE are not null
january_2016_cary_data = uber_data[
    (uber_data['START_DATE*'].dt.year == 2016) & (uber_data['START_DATE*'].dt.month == 1) &
    (uber_data['END_DATE*'].dt.year == 2016) & (uber_data['END_DATE*'].dt.month == 1) &
    (uber_data['START_DATE*'].notnull()) & (uber_data['END_DATE*'].notnull()) &
    (uber_data['START*'] == 'Cary')
]
#january_2016_cary_data.reset_index(inplace=True,drop=True)
# Step 3: Display the result
january_2016_cary_data
# Out:
#            START_DATE*           END_DATE* CATEGORY* START*        STOP*  \
# 7  2016-01-07 13:27:00 2016-01-07 13:33:00  Business   Cary         Cary
# 8  2016-01-10 08:05:00 2016-01-10 08:25:00  Business   Cary  Morrisville
# 28 2016-01-15 11:43:00 2016-01-15 12:03:00  Business   Cary       Durham
# 30 2016-01-18 14:55:00 2016-01-18 15:06:00  Business   Cary         Cary
# 34 2016-01-20 10:36:00 2016-01-20 11:11:00  Business   Cary      Raleigh
# 37 2016-01-21 14:25:00 2016-01-21 14:29:00  Business   Cary         Cary
# 38 2016-01-21 14:43:00 2016-01-21 14:51:00  Business   Cary         Cary
# 39 2016-01-21 16:01:00 2016-01-21 16:06:00  Business   Cary         Cary
# 43 2016-01-26 17:17:00 2016-01-26 17:22:00  Business   Cary         Cary
# 44 2016-01-26 17:27:00 2016-01-26 17:29:00  Business   Cary         Cary
# 45 2016-01-27 09:24:00 2016-01-27 09:31:00  Business   Cary         Cary
# 46 2016-01-27 10:19:00 2016-01-27 10:48:00  Business   Cary      Raleigh
# ...

# %%
#uber_data.sort_values(by='MILES*')
uber_data.sort_values(by='MILES*',ascending=False)
# Out:
#              START_DATE*           END_DATE* CATEGORY*            START*  \
# 1155                 NaT                 NaT       NaN               NaN
# 269  2016-03-25 16:52:00 2016-03-25 22:22:00  Business             Latta
# 270  2016-03-25 22:54:00 2016-03-26 01:39:00  Business      Jacksonville
# 881  2016-10-30 15:22:00 2016-10-30 18:23:00  Business         Asheville
# 776  2016-09-27 21:01:00 2016-09-28 02:37:00  Business  Unknown Location
# ...                  ...                 ...       ...               ...
# 1121 2016-12-27 12:53:00 2016-12-27 12:57:00  Business           Kar?chi
# 1110 2016-12-24 22:04:00 2016-12-24 22:09:00  Business            Lahore
# 44   2016-01-26 17:27:00 2016-01-26 17:29:00  Business              Cary
# 420  2016-06-08 17:16:00 2016-06-08 17:18:00  Business              Soho
# 120  2016-02-17 16:38:00 2016-02-17 16:43:00  Business        Katunayaka
#
#                  STOP*   MILES*         PURPOSE*
# ...

# %%
uber_data.sort_values(by=['START*','MILES*'],ascending=[True,False])
# Out:
#              START_DATE*           END_DATE* CATEGORY*         START*  \
# 906  2016-11-04 21:04:00 2016-11-04 21:20:00  Business          Agnew
# 911  2016-11-06 10:50:00 2016-11-06 11:04:00  Business          Agnew
# 908  2016-11-05 08:34:00 2016-11-05 08:43:00  Business          Agnew
# 910  2016-11-05 19:20:00 2016-11-05 19:28:00  Business          Agnew
# 879  2016-10-30 12:58:00 2016-10-30 13:18:00  Business         Almond
# ...                  ...                 ...       ...            ...
# 889  2016-11-01 17:35:00 2016-11-01 17:42:00  Business    Whitebridge
# 890  2016-11-01 19:14:00 2016-11-01 19:20:00  Business    Whitebridge
# 516  2016-07-05 16:48:00 2016-07-05 16:52:00  Business    Whitebridge
# 870  2016-10-28 18:13:00 2016-10-28 20:07:00  Business  Winston Salem
# 1155                 NaT                 NaT       NaN            NaN
#
#             STOP*   MILES*         PURPOSE*   MILES_CAT
# 906          Cory      4.3              NaN  short trip
# ...

# %%
import numpy as np
uber_data["MILES_CAT"]=np.where(uber_data['MILES*']>100,"Long trip","short trip")
uber_data.head()
# Out:
#           START_DATE*           END_DATE* CATEGORY*       START*  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#              STOP*  MILES*         PURPOSE*   MILES_CAT
# 0      Fort Pierce     5.1   Meal/Entertain  short trip
# 1      Fort Pierce     5.0              NaN  short trip
# 2      Fort Pierce     4.8  Errand/Supplies  short trip
# 3      Fort Pierce     4.7          Meeting  short trip
# 4  West Palm Beach    63.7   Customer Visit  short trip

# %%
#miles<=100----->short trip
import numpy as np
uber_data['MILES_CAT'] = np.where(uber_data['MILES*'] <= 100, "Short trip",np.where(
    (uber_data['MILES*'] > 100) & (uber_data['MILES*'] <= 200), "Middle trip","Long trip"))
uber_data
# Out:
#              START_DATE*           END_DATE* CATEGORY*            START*  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
# 1155                 NaT                 NaT       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*   MILES_CAT
# ...

# %%
uber_data=uber_data.drop('nc',axis=1)

# %%
uber_data=uber_data.drop('MILES_SHORT',axis=1)

# %%
uber_data
# Out:
#              START_DATE*           END_DATE* CATEGORY*            START*  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
# 1155                 NaT                 NaT       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*   MILES_CAT
# ...

# %%
uber_data.groupby('START*')['MILES*'].agg('mean')
# Out:
# START*
# Agnew                2.775000
# Almond              15.200000
# Apex                 5.341176
# Arabi               17.000000
# Arlington            4.900000
#                       ...
# West University      2.200000
# Weston               4.000000
# Westpark Place       2.182353
# Whitebridge          4.020588
# Winston Salem      133.600000
# Name: MILES*, Length: 177, dtype: float64

# %%
grouped = uber_data.groupby('CATEGORY*')['MILES*'].agg(['sum', 'mean', 'max'])
print(grouped)
# Out:
#                sum       mean    max
# CATEGORY*
# Business   11487.0  10.655844  310.3
# Personal     717.7   9.320779  180.2
