# %%
import pandas as pd
data=pd.read_csv("C:\\Users\CVR\\Downloads\\customer_purchase_behavior.csv")
data
# Out:
#     CustomerID  Age  Gender  Income  SpendingScore PurchaseCategory
# 0         1001   25    Male   50000             42      Electronics
# 1         1002   34  Female   62000             78         Clothing
# 2         1003   28    Male   58000             55        Groceries
# 3         1004   45  Female   72000             63        Furniture
# 4         1005   52    Male   81000             90      Electronics
# 5         1006   23  Female   45000             30         Clothing
# 6         1007   40    Male   75000             75        Groceries
# 7         1008   31  Female   64000             82        Furniture
# 8         1009   36    Male   67000             65      Electronics
# 9         1010   48  Female   83000             87         Clothing
# 10        1011   29    Male   60000             50        Groceries
# 11        1012   50  Female   87000             95        Furniture
# 12        1013   27    Male   56000             53      Electronics
# ...

# %%
data=data.drop(columns={'Age','Gender'})
data
# Out:
#     CustomerID  Income  SpendingScore PurchaseCategory
# 0         1001   50000             42      Electronics
# 1         1002   62000             78         Clothing
# 2         1003   58000             55        Groceries
# 3         1004   72000             63        Furniture
# 4         1005   81000             90      Electronics
# 5         1006   45000             30         Clothing
# 6         1007   75000             75        Groceries
# 7         1008   64000             82        Furniture
# 8         1009   67000             65      Electronics
# 9         1010   83000             87         Clothing
# 10        1011   60000             50        Groceries
# 11        1012   87000             95        Furniture
# 12        1013   56000             53      Electronics
# 13        1014   70000             73         Clothing
# 14        1015   74000             80        Groceries
# 15        1016   65000             68        Furniture
# ...

# %%
tdata=pd.read_csv("C:\\Users\\CVR\\Downloads\\Titanic-Dataset.csv")
tdata
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test=pd.read_csv("C:\\Users\\CVR\\Downloads\\archive (2)\\test.csv")
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
target=tdata['Survived']
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
numerical=tdata.select_dtypes(include=['number'])
y=numerical['Survived']
x=numerical.drop(columns='Survived',axis=1)
x.corr().round(2)
# Out:
#              PassengerId  Pclass   Age  SibSp  Parch  Fare
# PassengerId         1.00   -0.04  0.04  -0.06  -0.00  0.01
# Pclass             -0.04    1.00 -0.37   0.08   0.02 -0.55
# Age                 0.04   -0.37  1.00  -0.31  -0.19  0.10
# SibSp              -0.06    0.08 -0.31   1.00   0.41  0.16
# Parch              -0.00    0.02 -0.19   0.41   1.00  0.22
# Fare                0.01   -0.55  0.10   0.16   0.22  1.00

# %%
import seaborn as sns
sns.heatmap(x.corr().round(2),annot=True,cmap="coolwarm")
# Out:
# <Axes: >

# %%
#Label Encoding is used for Ordinal Data
from sklearn.preprocessing import LabelEncoder
dataset={'Difficulty':['Easy','Medium','Hard','Medium','Easy'],
        'Test Score':[50,60,70,80,90]}
df=pd.DataFrame(dataset)
encoder=LabelEncoder()
df['Difficulty_encoded']=encoder.fit_transform(df['Difficulty'])
print(df)
correlation=df['Difficulty_encoded'].corr(df['Test Score'])
print("Correlation:",correlation)
# Out:
#   Difficulty  Test Score  Difficulty_encoded
# 0       Easy          50                   0
# 1     Medium          60                   2
# 2       Hard          70                   1
# 3     Medium          80                   2
# 4       Easy          90                   0
# Correlation: 0.0

# %%
#one-hot encoding is used to convert categorical data into numerical data
dataset={'Color':['Red','Blue','Green','Blue','Red'],
        'Test Score':[50,60,70,80,90]}
df=pd.DataFrame(dataset)
df_encoded=pd.get_dummies(df,columns=['Color'])
print(df_encoded)
correlation=df_encoded['Color_Red'].corr(df_encoded['Test Score'])
print("Correlation with Red:",correlation)
# Out:
#    Test Score  Color_Blue  Color_Green  Color_Red
# 0          50       False        False       True
# 1          60        True        False      False
# 2          70       False         True      False
# 3          80        True        False      False
# 4          90       False        False       True
# Correlation with Red: -1.2819751242557094e-17
