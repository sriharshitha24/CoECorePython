# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("C:\\Users\\CVR\Desktop\\pythonProject1\\25-01-25\\train.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.barplot(data,x='Pclass',y='Survived',errorbar=None)
plt.title('Survival Rate by passenger class')
plt.xlabel('Passenger Class')
plt.ylabel('Survival Rate')
plt.show()

# %%
sns.scatterplot(data,x='Age',y='Fare',hue='Survived',palette='coolwarm',alpha=0.6)
plt.title('Age vs Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
subset=data[['Age','Fare','Pclass','Survived']]
sns.pairplot(subset,hue='Survived',palette='coolwarm',diag_kind='kde')
plt.suptitle('Pairwise Relationships',y=1.02)
plt.show()
# Out:
# C:\Users\CVR\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
numeric_cols=data.select_dtypes(include='number')
corr_matrix=numeric_cols.corr()
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm',linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()
